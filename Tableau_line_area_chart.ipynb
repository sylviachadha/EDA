# %% [markdown]
# # Line and Area Chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Scatterplot

# %% [markdown]
# Based on sales made to customer, what profit do we earn from that customer

# %% [markdown]
# ![image.png](attachment:image.png)
