# %% [markdown]
# ## Measurement_Scales

# %% [markdown]
# ![Xnip2022-07-21_16-21-26.jpg](attachment:Xnip2022-07-21_16-21-26.jpg)

# %% [markdown]
# ![Xnip2022-07-21_16-45-18.jpg](attachment:Xnip2022-07-21_16-45-18.jpg)

# %% [markdown]
# ## Types of Data

# %% [markdown]
# ![Xnip2022-07-21_16-29-36.jpg](attachment:Xnip2022-07-21_16-29-36.jpg)

# %% [markdown]
# # Linear and Non-Linear (Data)

# %% [markdown]
# ![image.png](attachment:image.png)
