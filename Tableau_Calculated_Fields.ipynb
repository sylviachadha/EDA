# %% [markdown]
# ## Calculated Fields

# %% [markdown]
# - Calculated field to create a new column from existing column.
# - is-else conditional statement in tableau.
# - regular expression to clean text column.

# %% [markdown]
# ![image.png](attachment:image.png)
