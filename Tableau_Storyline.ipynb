# %% [markdown]
# # Storyline

# %% [markdown]
# A Storyline sheet. You can drag worksheets as well as drag dashboard in the storyline. You can drag only 1 item not multiple items as in case of a dashboard.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Annotation

# %% [markdown]
# ![image.png](attachment:image.png)
