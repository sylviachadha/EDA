# %% [markdown]
# ## Highlighting

# %% [markdown]
# To see only women gender, highlight from filter.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Highlight a particular age group.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Filters

# %% [markdown]
# Drag gender to filters, you get a pop up. Choose select from list.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Quick Filter

# %% [markdown]
# Select 'Show filter' option to get a quick filter.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As seen below we can directly select from the quick filter now.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Creating quick filter for gender and age.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These quick filters can be of different types as well-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Apply same filter across different worksheets

# %% [markdown]
# Incase we want to put this year filter across all worksheets using this data source.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As shown below, before applying to all worksheets and after applying to all worksheets.

# %% [markdown]
# ![image.png](attachment:image.png)
