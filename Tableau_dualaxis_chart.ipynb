# %% [markdown]
# # Dual Axis Chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To convert above to dual-axis chart-

# %% [markdown]
# Click on target & choose dual-axis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After changing to dual-axis u also need to synchronise axis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
