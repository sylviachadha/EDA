# %% [markdown]
# # Export

# %% [markdown]
# Export worksheets as images or other files. Then can put into power points or word document etc.

# %% [markdown]
# On tableau public, on your image just do save image as option-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On locally installed Tableau can use below option-

# %% [markdown]
# Worksheet-> Export -> Image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# While copying image u can change the position of legend as well.
