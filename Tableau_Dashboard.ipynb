# %% [markdown]
# ## Dashboard

# %% [markdown]
# Able to choose device type on which dashboard would be viewed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The individual sheets for visuals can be picked and put up in the dashboard. For e.g. below we had created 2 sheets Age and Balance which can be put in Dashboard.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interactive Dashboards
#
# We can also add filters on top for interactive options.
