# %% [markdown]
# # Maps

# %% [markdown]
# - Geographical data in tableau
# - Geographical information identified with globe symbol.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Hierarchies

# %% [markdown]
# We would need hierarchy when we have elements of geographical information in data. e.g. city, country and state recognised as geographical data.

# %% [markdown]
# To create hierarchy take an element and drag it onto its parent element & u get a dialog box create hierarchy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Add state as well to hierarchy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Below each dot/data point represents a country, state and then city as we go down on hierarchy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Choosing color palette

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You use latitude and longitude fields to create a map.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To change background of map-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In case a field/variable is not identified as geographical, u can change urself.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now region changed to globe instead of text.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# UK = England + Northern Ireland + Scotland + Wales

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Change from automatic to map

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We get a map of UK

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Demographic information examples include: age, race, ethnicity, gender, marital status, income, education, and employment.

# %% [markdown]
# Labelling the map with count of customers in each region

# %% [markdown]
# ![image.png](attachment:image.png)
