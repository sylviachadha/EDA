# %% [markdown]
# # Data Visualizations

# %% [markdown]
#  ## <font color=blue> 1. Relationships

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color=blue> 2. Trend

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color=blue> 3. Distributions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color=blue> 4. Visualize single value/metrics or KPI's

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color=blue> 5. Visualize a flow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color=blue> 6. Part-to-whole Charts (show percentage by each)

# %% [markdown]
# ![image.png](attachment:image.png)
