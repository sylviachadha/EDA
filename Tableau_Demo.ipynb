# %% [markdown]
# # Tableau

# %% [markdown]
# ## Loading Data

# %% [markdown]
# 1. To load a csv file, use the text file option.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Data loaded, shows 4014 rows and 9 attributes. This is metapane view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. The data type for each field is detected automatically as shown above.
# - Text column idetified as Abc
# - Numerical column will be seen as measures so u see # symbol.
# - For Date column, calender symbol.
# - For location column, globe symbol.

# %% [markdown]
# Tableau is able to identify below columns-
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Change automatically detected data type
#
# E.g. we want to change region data type to geographical.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# E.g. changing date from string/Abc data type to calender
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Check metadata details

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Worksheet, Dashboard, Story

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Each Worksheet has a visual. Dashboard is a collection of visuals (where u drag drop sheets whose visuals you want)

# %% [markdown]
# ## Worksheet - Dimensions & Measures

# %% [markdown]
# In datapane you will have 2 divisons - Categorical columns (Dimensions) and Numerical columns (Measures)

# %% [markdown]
# ![image.png](attachment:image.png)
