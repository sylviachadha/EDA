# %% [markdown]
# # Time Series Plots

# %% [markdown]
# When start working with Time Series data check-
#
# 1. For how long is the data like 1 year or 10 year data etc.
# 2. If Date column is datetime data type & if u want to make that column as index.
# 3. How data columns relates to real world entities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/sylvia/Desktop/2024/Job_Skills/5. EDA_Visualizations/Udemy'

# %%
df = pd.read_csv('data/daily-temperature.csv')
df
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   datetime64[ns]
#  1   Temp    3650 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 57.2 KB

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %% [markdown]
# ### rc.Params

# %% [markdown]
# - *<font color=blue>By modifying plt.rcParams, you can customize the look and feel of your plots globally, so that all subsequent plots will adhere to these settings without needing to specify them each time you create a plot.*
#
# - In rcParams, "rc" stands for "run commands." The term comes from the concept of "run commands" in configuration files, which are often referred to as "rc files" in Unix and Linux systems. These files typically contain settings and configurations that are read and applied when a program starts. Similarly, in Matplotlib, rcParams contains the settings and configurations that determine the default behavior and appearance of plots.
#
# - plt.rcParams is a dictionary-like object in the Matplotlib library in Python that contains configuration settings for customizing the appearance of plots. These settings, often referred to as "rc settings" or "rc parameters," control the default styles and behaviors of Matplotlib plots.
#
# You can use plt.rcParams to change a wide range of settings, such as:
#
# - Figure size and DPI - "dots per inch" it is a measure of the resolution of a figure. It determines how many pixels per inch are used to render the figure.
# - Line styles and widths
# - Font sizes and styles
# - Colors and color maps
# - Axes properties
# - Ticks and labels
# - Legends and grids

# %%
plt.rcParams['figure.figsize'] = [8,4]
plt.rcParams['figure.dpi'] = 140

# 140 dots per inch (DPI). This means that for every inch of the figure, there will be 140 pixels. 
# This affects the clarity and size of the figure when displayed or saved.

# %% [markdown]
# # 1. Line Plot

# %%
df.plot();

# %% [markdown]
# Above figure shows some kind of sinusodial pattern. This data is collected from Southern hemisphere. We can observe this from plot cz in middle of every year i.e. May, June temp. is low which happens in southern hemisphere cz in northern hemisphere middle of every year temperature is high.

# %%
df.plot()
plt.ylabel('Temperature')
plt.title('Line Plot');

# %% [markdown]
# ## Ten Subplots for 10 years data

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.tail()
# Out:
#             Temp
# Date
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0

# %%
years = df.index.year.unique()
years
# Out:
# Index([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990], dtype='int32', name='Date')

# %%
grouped = df.groupby(df.index.year)
grouped

# %%
grouped.groups.keys()
# Out:
# dict_keys([1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990])

# %%
grouped.get_group(1981)
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1981-12-27  15.5
# 1981-12-28  13.3
# 1981-12-29  15.6
# 1981-12-30  15.2
# 1981-12-31  17.4
#
# [365 rows x 1 columns]

# %%
grouped.get_group(1981)['Temp'].values
# Out:
# array([20.7, 17.9, 18.8, 14.6, 15.8, 15.8, 15.8, 17.4, 21.8, 20. , 16.2,
#        13.3, 16.7, 21.5, 25. , 20.7, 20.6, 24.8, 17.7, 15.5, 18.2, 12.1,
#        14.4, 16. , 16.5, 18.7, 19.4, 17.2, 15.5, 15.1, 15.4, 15.3, 18.8,
#        21.9, 19.9, 16.6, 16.8, 14.6, 17.1, 25. , 15. , 13.7, 13.9, 18.3,
#        22. , 22.1, 21.2, 18.4, 16.6, 16.1, 15.7, 16.6, 16.5, 14.4, 14.4,
#        18.5, 16.9, 17.5, 21.2, 17.8, 18.6, 17. , 16. , 13.3, 14.3, 11.4,
#        16.3, 16.1, 11.8, 12.2, 14.7, 11.8, 11.3, 10.6, 11.7, 14.2, 11.2,
#        16.9, 16.7,  8.1,  8. ,  8.8, 13.4, 10.9, 13.4, 11. , 15. , 15.7,
#        14.5, 15.8, 16.7, 16.8, 17.5, 17.1, 18.1, 16.6, 10. , 14.9, 15.9,
#        13. ,  7.6, 11.5, 13.5, 13. , 13.3, 12.1, 12.4, 13.2, 13.8, 10.6,
#         9. , 10. ,  9.8, 11.5,  8.9,  7.4,  9.9,  9.3,  9.9,  7.4,  8.6,
#        11.9, 14. ,  8.6, 10. , 13.5, 12. , 10.5, 10.7,  8.1, 10.1, 10.6,
#         5.3,  6.6,  8.5, 11.2,  9.8,  5.9,  3.2,  2.1,  3.4,  5.4,  9.6,
# ...

# %%
df_list = []
for year in years:
        df = grouped.get_group(year)
        df.plot()
        df_list.append(df);

# %% [markdown]
# # 2. Heatmap

# %% [markdown]
# Heatmaps can be useful for visualizing time series data, especially when you want to show how a particular value changes over time in relation to two dimensions, such as time of day and day of the week, or year and month.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Simulate 10 years of monthly data
dates = pd.date_range(start='1/1/2010', end='12/31/2019', freq='M')
values = np.random.rand(len(dates))  # Random values for demonstration

# Create DataFrame
df = pd.DataFrame({'date': dates, 'value': values})
df.set_index('date', inplace=True)

# Add 'Year' and 'Month' columns
df['Year'] = df.index.year
df['Month'] = df.index.month

# Pivot the DataFrame to create a matrix for the heatmap
heatmap_data = df.pivot_table(values='value', index='Year', columns='Month', aggfunc='mean')

# Create the heatmap using Matplotlib
fig, ax = plt.subplots(figsize=(12, 8))
cax = ax.matshow(heatmap_data, cmap='YlGnBu')

# Add colorbar
fig.colorbar(cax)

# Set axis labels
ax.set_xticks(np.arange(heatmap_data.columns.size))
ax.set_xticklabels(heatmap_data.columns, rotation=90)
ax.set_yticks(np.arange(heatmap_data.index.size))
ax.set_yticklabels(heatmap_data.index)

# Set labels
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Heatmap of Values by Year and Month (2010-2019)')

# Show the plot
plt.show()

# %% [markdown]
# # 3. Boxplot

# %% [markdown]
# Purpose: Shows the distribution and outliers over time or grouped by periods.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Simulate 10 years of monthly data
dates = pd.date_range(start='1/1/2010', end='12/31/2019', freq='M')
values = np.random.rand(len(dates))  # Random values for demonstration

# Create DataFrame
df = pd.DataFrame({'date': dates, 'value': values})
df.set_index('date', inplace=True)

# Add 'Month' column
df['Month'] = df.index.month

# Prepare data for box plot
data = [df[df['Month'] == i]['value'].values for i in range(1, 13)]

# Create the box plot using Matplotlib
plt.figure(figsize=(12, 6))
plt.boxplot(data, labels=range(1, 13))
plt.title('Box Plot of Values by Month')
plt.xlabel('Month')
plt.ylabel('Value')
plt.show()
