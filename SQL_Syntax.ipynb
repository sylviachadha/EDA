# %% [markdown]
# # SQL Syntax

# %% [markdown]
# # *1. SQL SELECT STATEMENTS*

# %% [markdown]
# <font color=blue>1. SELECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>2. SELECT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>3. WHERE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>4. ORDER BY <br>

# %% [markdown]
# Normally you ORDER BY on the columns you SELECT, as selected columns only appear in result

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <font color=blue>5. DISTINCT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>6. GROUP BY

# %% [markdown]
# Groupby on categorical column (e.g. rating, customer_id) and aggregations on numerical column (e.g. replacement_cost, amount)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>7. HAVING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # *2. SQL JOIN STATEMENTS*

# %% [markdown]
# <font color=blue>1. INNER JOIN

# %% [markdown]
# Only matching entries in both tables. SYMMERTICAL join.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>2. LEFT JOIN / LEFT OUTER JOIN

# %% [markdown]
# Not a symmetrical join, order of table matters.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>3. RIGHT JOIN / RIGHT OUTER JOIN

# %% [markdown]
# Not a symmetrical join, order of table matters.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>4. FULL OUTER JOIN

# %% [markdown]
# SYMMERTICAL join.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # *3. SQL TABLE STATEMENTS*

# %% [markdown]
# <font color=blue>1. CREATE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>2. DROP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>3. ALTER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # *4. UPDATE TABLE STATEMENTS*

# %% [markdown]
# <font color=blue>1. INSERT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>2. SET

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>3. DELETE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color=blue>4. TRUNCATE

# %% [markdown]
# ![image.png](attachment:image.png)
