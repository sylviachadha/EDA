# %% [markdown]
# # Formatting

# %% [markdown]
# ## Adding Colors

# %% [markdown]
# Data science is not just about crunching numbers, it is a form of art, a form of communication, a v.creative activity/profession.

# %% [markdown]
# Add color by sum of sales. It is not discrete color now, it is continuous color.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Another approach, add color by region.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Adding Labels

# %% [markdown]
# Foe Ease of understanding. Look for ways to communicate information in a v.simple form so people do not have to put effort to understand it & extract information visually to what we r presenting to them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Format Label

# %% [markdown]
# To change formatting of labels. Make changes in Pane not axis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Format Axis

# %% [markdown]
# Choose format option-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This time you choose axis option and not pane.

# %% [markdown]
# ![image.png](attachment:image.png)
