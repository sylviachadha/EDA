# %% [markdown]
# # Pie chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For pie chart generally we prefer % instead of total number.

# %% [markdown]
# # Table Calculations

# %% [markdown]
# Replace the total number field with table calculation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The triangle indicates there is a table calculation being performed here.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After table calculation, you get % in pie chart.

# %% [markdown]
# ![image.png](attachment:image.png)
