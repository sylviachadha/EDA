# %% [markdown]
# ## Worksheets

# %% [markdown]
# Normally 1 worksheet is created for 1 visual.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can save, open and share Tableau public notebook.

# %% [markdown]
# ### Customizing a visualization using Marks

# %% [markdown]
# You can change color of plot, change width of bars (in bar chart) using size, give customised tooltip etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Complexity of visuals

# %% [markdown]
# The more variables you add, the complexity of your chart increases, the readability comes down. We have charts below with 1,2 and 3 variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
