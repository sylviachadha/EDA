# %% [markdown]
# # Tableau Q&A

# %% [markdown]
# # 1. Line Chart vs Area Chart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Color Mapping

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As seen in 1st plot the dot is further away from axis still its color is lighter cz its profit margin is less 0.1 while a dot in below plot its color is darker cz its profit margin is greater 0.4. So **axis** are for checking Sales and Profit while **color** tells u about Profit margin. The colors are mappped (darkest shade of red and blue r marked as -0.5 and 0.5) this will depend on your data what u want to consider as good and bad values as per your requirement and then ur chart will depict each data points within those shading values as per your actual data points.

# %% [markdown]
# # 3. Calculated field using blend data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
