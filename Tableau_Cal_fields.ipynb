# %% [markdown]
# # Calculated Fields

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When u create calculated field & it is ok then u get msg 'calculation is valid'.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Total_Sales calculated field will appear under measures with symbol =#

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Visualization after calculated field.

# %% [markdown]
# ![image.png](attachment:image.png)
