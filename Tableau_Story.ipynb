# %% [markdown]
# ## Storycards

# %% [markdown]
# - Storycards are very powerful to explain your visual. They will act as a slideshow one after the other in new story tab.
# - Also all storycards will be completely interactive.

# %% [markdown]
# ![image.png](attachment:image.png)
